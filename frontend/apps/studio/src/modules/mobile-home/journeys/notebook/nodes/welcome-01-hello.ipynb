# %% [markdown]
# # Hello, Python!
#
# Welcome to Notebook Lab. In this notebook you will run your first Python code.
#
# Press the ▶ button on the cell below to run it.

# %%
print("Hello from Python!")

# %% [markdown]
# ## Try it yourself
#
# Change the message inside the quotes, then run the cell again.

# %%
print("Write your own message here!")

# %% [markdown]
# Nice work! You just ran Python code. Tap **Mark complete** when you are ready to continue.
