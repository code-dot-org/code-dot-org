# %% [markdown]
# # Words and Code
#
# In Python, words and sentences are called **strings**. You can combine them with `+`.
#
# Run the cell below to see how it works.

# %%
first = "Hello"
second = "world"
print(first + ", " + second + "!")

# %% [markdown]
# ## Your name
#
# Change `"your name"` to your actual name and run the cell.

# %%
name = "your name"
print("My name is " + name + ".")
print("Nice to meet you, " + name + "!")

# %% [markdown]
# Great — you just used **variables** to store text. Tap **Mark complete** to move on.
