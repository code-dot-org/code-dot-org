# %% [markdown]
# # You Built Something
#
# In the last three notebooks you learned:
#
# - How to **run code** with the ▶ button
# - How to work with **strings** (text)
# - How to use **variables** as dials
#
# Now put it all together. Run the cell below — then change whatever you like.

# %%
name = "Pythonista"
lessons = 4
subject = "Python Notebook Lab"

print("Name:", name)
print("Lessons completed:", lessons)
print("Course:", subject)
print()
print(name + " has finished " + subject + ". Great work!")

# %% [markdown]
# ## What's next?
#
# Your notebook is saved. You can return to it any time from the Notebooks tab.
#
# Tap **Mark complete** to finish the onboarding path.
